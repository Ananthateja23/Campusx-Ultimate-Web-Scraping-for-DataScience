# %% [markdown]
# # 4. Fetching webpage with `Requests`
#
# - URL: `https://www.bbc.com/sport/football/premier-league/top-scorers`

# %%
# import libraries

import requests
from bs4 import BeautifulSoup

# %%
# Get request

url = "https://www.bbc.com/sport/football/premier-league/top-scorers"

response = requests.get(url)

# %%
# check for errors

response.raise_for_status()

# %%
print(response.raise_for_status())
# Out:
# None

# %%
# status code 

response.status_code
# Out:
# 200

# %%
# text (string format)

response.text[:200]
# Out:
# '<!DOCTYPE html><html lang="en-GB" class="no-js"><head><meta charSet="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1" /><title data-rh="true">Premier League Top Scorers - B'

# %%
type(response.text)
# Out:
# str

# %%
# content (binary format)

response.content[:200]
# Out:
# b'<!DOCTYPE html><html lang="en-GB" class="no-js"><head><meta charSet="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1" /><title data-rh="true">Premier League Top Scorers - B'

# %%
type(response.content)
# Out:
# bytes

# %% [markdown]
# - can use either `content` or `text` attribute to create the soup object
# - with `text`, we must be certain about the encoding
# - with `content`, we let Beautiful Soup handle the encoding mostly

# %%
# soup object

soup = BeautifulSoup(response.content, "html.parser")

# %%
# when you are learning, uncomment the below code and execute it
# print(soup.prettify())

# %% [markdown]
# # 5. HTML parsing with `Beautiful Soup`: A Mini Project
#
# - scrape data from a public website
# - organize the data as a dataframe
# - export the data as an excel sheet

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# Out:
# c:\Users\ANANTH\anaconda3\envs\web_scraping\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    print("Successful!")
# Out:
# Successful!

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    print("Successful!")
    # print(soup.prettify())
# Out:
# Successful!

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    print(len(soup.find_all("tbody")))
    print(soup.find_all("tbody"))
# Out:
# 2
# ...

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    print(len(soup.find("tbody").find_all("tr", class_="ssrcss-hpa5ss-TableRowBody e1icz100")))
    print(soup.find("tbody").find_all("tr", class_="ssrcss-hpa5ss-TableRowBody e1icz100"))
# Out:
# 29
# ...

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_="ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        print(player)
        break
# Out:
# <tr class="ssrcss-hpa5ss-TableRowBody e1icz100"><td class="ssrcss-63h33v-StyledTableData ef9ipf1"><div class="ssrcss-19jmwd7-CellWrapper ef9ipf0" value="1"><div class="ssrcss-wjp01q-RankAndBadgeWrapper e1n6h4mf2"><span class="ssrcss-1xljqjf-Rank e1n6h4mf1">1</span><div class="ssrcss-pp8itw-BadgeWrapper e1n6h4mf0"><div class="ssrcss-bdya4g-MobileOnlyWrapper e1v3gc7i1"><div class="ssrcss-1ij97kg-BadgeContainer ezmsq4q1" data-testid="badge-container-manchester-city" size="20"><img alt="" aria-hidden="true" class="ssrcss-1knyx38-BadgeImage ezmsq4q0" data-testid="badge-img-manchester-city" src="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/manchester-city.e4f9593ae9.svg"/></div></div><div class="ssrcss-dngukv-DesktopOnlyWrapper e1v3gc7i0"><div class="ssrcss-1b9x5pa-BadgeContainer ezmsq4q1" data-testid="badge-container-manchester-city" size="24"><img alt="" aria-hidden="true" class="ssrcss-1knyx38-BadgeImage ezmsq4q0" data-testid="badge-img-manchester-city" src=
# ...

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_="ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        print(player.find("div", class_="ssrcss-1rqvnx-PlayerName e1n8xy5b1"))
        break
# Out:
# <div class="ssrcss-1rqvnx-PlayerName e1n8xy5b1">E. Haaland</div>

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_="ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        print(player.find("div", class_="ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True))
        break
# Out:
# E. Haaland

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_="ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        print(player.find("div", class_="ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True))
        # break
# Out:
# E. Haaland
# Igor Thiago
# A. Semenyo
# João Pedro
# H. Ekitiké
# D. Calvert-Lewin
# D. Welbeck
# V. Gyökeres
# H. Wilson
# Bruno Guimarães
# B. Mbeumo
# C. Palmer
# M. Rogers
# J. Bowen
# Richarlison
# R. Jiménez
# E. Fernández
# M. Gibbs-White
# B. Šeško
# O. Watkins
# J. Kroupi
# J. Mateta
# Bruno Fernandes
# P. Foden
# K. Schade
# N. Woltemade
# I. Sarr
# J. Anthony
# Z. Flemming

# %%
player_names = []

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_="ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        player_name = player.find("div", class_="ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        player_names.append(player_name)
        # break

# %%
print(player_names)
# Out:
# ['E. Haaland', 'Igor Thiago', 'A. Semenyo', 'João Pedro', 'H. Ekitiké', 'D. Calvert-Lewin', 'D. Welbeck', 'V. Gyökeres', 'H. Wilson', 'Bruno Guimarães', 'B. Mbeumo', 'C. Palmer', 'M. Rogers', 'J. Bowen', 'Richarlison', 'R. Jiménez', 'E. Fernández', 'M. Gibbs-White', 'B. Šeško', 'O. Watkins', 'J. Kroupi', 'J. Mateta', 'Bruno Fernandes', 'P. Foden', 'K. Schade', 'N. Woltemade', 'I. Sarr', 'J. Anthony', 'Z. Flemming']

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_ = "ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        player_name = player.find("div", class_ = "ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        print(player.find("div", class_ = "ssrcss-cfavl3-TeamsSummary e1n8xy5b0"))
        break
# Out:
# <div class="ssrcss-cfavl3-TeamsSummary e1n8xy5b0">Man City</div>

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_ = "ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        # player_name = player.find("div", class_ = "ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        print(player.find("div", class_ = "ssrcss-cfavl3-TeamsSummary e1n8xy5b0").get_text(strip = True))
# Out:
# Man City
# Brentford
# Man City
# Chelsea
# Liverpool
# Leeds
# Brighton
# Arsenal
# Fulham
# Newcastle
# Man Utd
# Chelsea
# Aston Villa
# West Ham
# Spurs
# Fulham
# Chelsea
# Nottm Forest
# Man Utd
# Aston Villa
# Bournemouth
# Crystal Palace
# Man Utd
# Man City
# Brentford
# Newcastle
# Crystal Palace
# Burnley
# Burnley

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_ = "ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        # player_name = player.find("div", class_ = "ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        # team_name   = player.find("div", class_ = "ssrcss-cfavl3-TeamsSummary e1n8xy5b0").get_text(strip = True)
        # player_names.append(player_name)
        # team_names.append(team_name)
        print(player.find("div", class_="ssrcss-1fyor78-CellWrapper ef9ipf0"))
        break
# Out:
# <div class="ssrcss-1fyor78-CellWrapper ef9ipf0" value="22">22</div>

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_ = "ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        # player_name = player.find("div", class_ = "ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        # team_name   = player.find("div", class_ = "ssrcss-cfavl3-TeamsSummary e1n8xy5b0").get_text(strip = True)
        # player_names.append(player_name)
        # team_names.append(team_name)
        print(player.find("div", class_="ssrcss-1fyor78-CellWrapper ef9ipf0").get_text(strip = True))
        print(type(player.find("div", class_="ssrcss-1fyor78-CellWrapper ef9ipf0").get_text(strip = True)))
        break
# Out:
# 22
# <class 'str'>

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_ = "ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        # player_name  = player.find("div", class_ = "ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        # team_name    = player.find("div", class_ = "ssrcss-cfavl3-TeamsSummary e1n8xy5b0").get_text(strip = True)
        # goals_scored = int(player.find("div", class_="ssrcss-1fyor78-CellWrapper ef9ipf0").get_text(strip = True))
        # player_names.append(player_name)
        # team_names.append(team_name)
        # goals.append(goals_scored)

        # assisted value
        print(player.find("div", class_ = "ssrcss-ero735-CellWrapper ef9ipf0"))
        print(type(player.find("div", class_ = "ssrcss-ero735-CellWrapper ef9ipf0").get_text(strip = True)))
        break
# Out:
# <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="7">7</div>
# <class 'str'>

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_ = "ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        # player_name  = player.find("div", class_ = "ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        # team_name    = player.find("div", class_ = "ssrcss-cfavl3-TeamsSummary e1n8xy5b0").get_text(strip = True)
        # goals_scored = int(player.find("div", class_="ssrcss-1fyor78-CellWrapper ef9ipf0").get_text(strip = True))
        # player_names.append(player_name)
        # team_names.append(team_name)
        # goals.append(goals_scored)

        # played value
        print(player.find("div",class_ = "ssrcss-ero735-CellWrapper ef9ipf0"))
        print(type(player.find("div", class_ = "ssrcss-ero735-CellWrapper ef9ipf0").get_text(strip = True)))
        break
# Out:
# <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="7">7</div>
# <class 'str'>

# %% [markdown]
# - the attributes `assists` and `played` had the same classid  `ssrcss-ero735-CellWrapper ef9ipf0`

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_ = "ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        # player_name  = player.find("div", class_ = "ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        # team_name    = player.find("div", class_ = "ssrcss-cfavl3-TeamsSummary e1n8xy5b0").get_text(strip = True)
        # goals_scored = int(player.find("div", class_="ssrcss-1fyor78-CellWrapper ef9ipf0").get_text(strip = True))
        # player_names.append(player_name)
        # team_names.append(team_name)
        # goals.append(goals_scored)

        # played value
        print(player.find_all("div", class_ = "ssrcss-ero735-CellWrapper ef9ipf0"))
        print(len(player.find_all("div", class_ = "ssrcss-ero735-CellWrapper ef9ipf0")))
        break
# Out:
# [<div class="ssrcss-ero735-CellWrapper ef9ipf0" value="7">7</div>, <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="7">7</div>, <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="28">28</div>, <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="28">28</div>, <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="0.85">0.85</div>, <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="106">106</div>, <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="106">106</div>, <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="98">98</div>, <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="22%">22%</div>, <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="49%">49%</div>]
# 10

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_ = "ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        # player_name  = player.find("div", class_ = "ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        # team_name    = player.find("div", class_ = "ssrcss-cfavl3-TeamsSummary e1n8xy5b0").get_text(strip = True)
        # goals_scored = int(player.find("div", class_="ssrcss-1fyor78-CellWrapper ef9ipf0").get_text(strip = True))
        # player_names.append(player_name)
        # team_names.append(team_name)
        # goals.append(goals_scored)

        # played value
        for div_tag in player.find_all("div", class_ = "ssrcss-ero735-CellWrapper ef9ipf0"):
            print(div_tag)
        break
# Out:
# <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="7">7</div>
# <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="7">7</div>
# <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="28">28</div>
# <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="28">28</div>
# <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="0.85">0.85</div>
# <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="106">106</div>
# <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="106">106</div>
# <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="98">98</div>
# <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="22%">22%</div>
# <div class="ssrcss-ero735-CellWrapper ef9ipf0" value="49%">49%</div>

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_ = "ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        # player_name  = player.find("div", class_ = "ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        # team_name    = player.find("div", class_ = "ssrcss-cfavl3-TeamsSummary e1n8xy5b0").get_text(strip = True)
        # goals_scored = int(player.find("div", class_="ssrcss-1fyor78-CellWrapper ef9ipf0").get_text(strip = True))
        stats = player.find_all("div", class_ = "ssrcss-ero735-CellWrapper ef9ipf0")
        assists_made = stats[0]
        matches_played = stats[2]
        shots_taken = stats[-3]

        print(f"assists_made   : {type(assists_made)}")
        print(f"matches_played : {type(matches_played)}")
        print(f"shots_taken    : {type(shots_taken)}")

        # player_names.append(player_name)
        # team_names.append(team_name)
        # goals.append(goals_scored)
        break
# Out:
# assists_made   : <class 'bs4.element.Tag'>
# matches_played : <class 'bs4.element.Tag'>
# shots_taken    : <class 'bs4.element.Tag'>

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_ = "ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        # player_name  = player.find("div", class_ = "ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        # team_name    = player.find("div", class_ = "ssrcss-cfavl3-TeamsSummary e1n8xy5b0").get_text(strip = True)
        # goals_scored = int(player.find("div", class_="ssrcss-1fyor78-CellWrapper ef9ipf0").get_text(strip = True))
        stats = player.find_all("div", class_ = "ssrcss-ero735-CellWrapper ef9ipf0")
        assists_made = stats[0].get_text(strip = True)
        matches_played = stats[2].get_text(strip = True)
        shots_taken = stats[-3].get_text(strip = True)

        print(f"assists_made   : {assists_made} {type(assists_made)}")
        print(f"matches_played : {matches_played} {type(matches_played)}")
        print(f"shots_taken    : {shots_taken} {type(shots_taken)}")

        # player_names.append(player_name)
        # team_names.append(team_name)
        # goals.append(goals_scored)
        break
# Out:
# assists_made   : 7 <class 'str'>
# matches_played : 28 <class 'str'>
# shots_taken    : 98 <class 'str'>

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_ = "ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:
        player_name  = player.find("div", class_ = "ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        team_name    = player.find("div", class_ = "ssrcss-cfavl3-TeamsSummary e1n8xy5b0").get_text(strip = True)
        goals_scored = int(player.find("div", class_="ssrcss-1fyor78-CellWrapper ef9ipf0").get_text(strip = True))
        stats = player.find_all("div", class_ = "ssrcss-ero735-CellWrapper ef9ipf0")
        assists_made = int(stats[0].get_text(strip = True))
        matches_played = int(stats[2].get_text(strip = True))
        shots_taken = int(stats[-3].get_text(strip = True))
        print(assists_made, matches_played, shots_taken)


        # player_names.append(player_name)
        # team_names.append(team_name)
        # goals.append(goals_scored)
# Out:
# 7 28 98
# 1 29 67
# 4 28 67
# 5 29 57
# 4 26 63
# 1 26 54
# 0 28 38
# 0 28 42
# 6 27 58
# 4 23 32
# 3 24 57
# 1 18 41
# 5 29 66
# 5 29 65
# 3 24 39
# 3 28 62
# 3 28 55
# 2 29 63
# 1 24 51
# 1 28 57
# 0 24 29
# 0 23 54
# 14 26 64
# 3 25 51
# 3 26 44
# 2 25 30
# 1 19 34
# 1 28 38
# 0 20 31

# %%
player_names = []
team_names = []
goals = []
assists = []
num_matches = []
shots = []

# %%
try:
    url = "https://www.bbc.com/sport/football/premier-league/top-scorers"
    response = requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    soup = BeautifulSoup(response.content, "html.parser")
    players = soup.find("tbody").find_all("tr", class_ = "ssrcss-hpa5ss-TableRowBody e1icz100")
    for player in players:

        # extract the attribute values
        player_name  = player.find("div", class_ = "ssrcss-1rqvnx-PlayerName e1n8xy5b1").get_text(strip = True)
        team_name    = player.find("div", class_ = "ssrcss-cfavl3-TeamsSummary e1n8xy5b0").get_text(strip = True)
        goals_scored = int(player.find("div", class_="ssrcss-1fyor78-CellWrapper ef9ipf0").get_text(strip = True))
        stats = player.find_all("div", class_ = "ssrcss-ero735-CellWrapper ef9ipf0")
        assists_made = int(stats[0].get_text(strip = True))
        matches_played = int(stats[2].get_text(strip = True))
        shots_taken = int(stats[-3].get_text(strip = True))

        # store the attribute values into lists
        player_names.append(player_name)
        team_names.append(team_name)
        goals.append(goals_scored)
        assists.append(assists_made)
        num_matches.append(matches_played)
        shots.append(shots_taken)

    # create a dictionary
    data = {
        "players": player_names,
        "teams": team_names,
        "goals": goals,
        "assists": assists,
        "matches": num_matches,
        "shots": shots
    }
    
    # create a dataframe
    df_players = pd.DataFrame(data)

# %%
df_players
# Out:
#              players           teams  goals  assists  matches  shots
# 0         E. Haaland        Man City     22        7       28     98
# 1        Igor Thiago       Brentford     18        1       29     67
# 2         A. Semenyo        Man City     15        4       28     67
# 3         João Pedro         Chelsea     14        5       29     57
# 4         H. Ekitiké       Liverpool     11        4       26     63
# 5   D. Calvert-Lewin           Leeds     10        1       26     54
# 6         D. Welbeck        Brighton     10        0       28     38
# 7        V. Gyökeres         Arsenal     10        0       28     42
# 8          H. Wilson          Fulham      9        6       27     58
# 9    Bruno Guimarães       Newcastle      9        4       23     32
# 10         B. Mbeumo         Man Utd      9        3       24     57
# 11         C. Palmer         Chelsea      9        1       18     41
# 12         M. Rogers     Aston Villa      8        5       29     66
# ...

# %%
df_players.head()
# Out:
#        players      teams  goals  assists  matches  shots
# 0   E. Haaland   Man City     22        7       28     98
# 1  Igor Thiago  Brentford     18        1       29     67
# 2   A. Semenyo   Man City     15        4       28     67
# 3   João Pedro    Chelsea     14        5       29     57
# 4   H. Ekitiké  Liverpool     11        4       26     63

# %%
df_players.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   players  29 non-null     str
#  1   teams    29 non-null     str
#  2   goals    29 non-null     int64
#  3   assists  29 non-null     int64
#  4   matches  29 non-null     int64
#  5   shots    29 non-null     int64
# dtypes: int64(4), str(2)
# memory usage: 1.5 KB

# %%
df_players.describe()
# Out:
#            goals    assists    matches      shots
# count  29.000000  29.000000  29.000000  29.000000
# mean    9.482759   2.862069  25.827586  51.965517
# std     3.531700   2.899805   3.059750  15.319182
# min     7.000000   0.000000  18.000000  29.000000
# 25%     8.000000   1.000000  24.000000  39.000000
# 50%     8.000000   3.000000  26.000000  54.000000
# 75%    10.000000   4.000000  28.000000  63.000000
# max    22.000000  14.000000  29.000000  98.000000

# %%
df_players.to_excel("EPL Top Scorers.xlsx", index = False)
